# %%
"""
@Josh Boquiren
OTIS Lab MUSC
6.26.2023
"""
# Out:
# '\n@Josh Boquiren\nOTIS Lab MUSC\n6.22.2023\n'

# %% [markdown]
# ## Pilot

# %%
#import libraries

#data manipulation
import numpy as np
import pandas as pd

#plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#directory and file manager
import os

#statistics
import scipy.stats as stats
import scipy.io as sio

# %%
#directories and animals

try:
    user = 'jboqu'

    main_dir = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\LC-PrL-DREADDs_Self-Admin_Analysis\cue_analysis\LC-PrL-DREADDs'%(user)
    main_results = os.path.join(main_dir, 'results')

    #all CueRein Data
    ALL_cueRein_dir = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\PFC Self-Admin Analysis\PFC Self Admin Data\CueRein'%(user)

    #project datasets folder in DropBox
    LCDD_basedir = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\LC-PrL DREADDs Self Admin Analysis\Controls'%(user)
    LCDD_cueRein_dir = os.path.join(LCDD_basedir, 'CueRein')
    LCDD_cueReinCNO_dir = os.path.join(LCDD_basedir, 'CueReinCNO')
    LCDD_cueReinPersist_dir = os.path.join(LCDD_basedir, 'CueReinPersist')
    LCDD_lastEXT_dir = os.path.join(LCDD_basedir, 'LastExt')

    #folders in repository
    LCDD_repository = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\LC-PrL-DREADDs_Self-Admin_Analysis\cue_analysis\LCDD'%(user)
    LCDD_results = os.path.join(LCDD_repository, 'results')
    LCDD_models = os.path.join(LCDD_repository, 'population_data')

    #cluster list files
    LCDD_cueRein_cluster_labels = np.load(os.path.join(LCDD_cueRein_dir, 'cluster_list_per_session_CueTests Control.npy'))
    LCDD_cueReinCNO_labels = np.load(os.path.join(LCDD_cueReinCNO_dir, 'cluster_list_per_session_CueTests Control.npy'))
    LCDD_cueReinPersist_labels = np.load(os.path.join(LCDD_cueReinPersist_dir, 'cluster_list_per_session_CueTests Control.npy'))

    #project datasets folder in DropBox
    Gi_basedir = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\LC-PrL DREADDs Self Admin Analysis\Gi-DREADDs'%(user)
    Gi_cueRein_dir = os.path.join(Gi_basedir, 'CueRein')
    Gi_cueReinCNO_dir = os.path.join(Gi_basedir, 'CueReinCNO')
    Gi_cueReinPersist_dir = os.path.join(Gi_basedir, 'CueReinPersist')
    Gi_lastEXT_dir = os.path.join(LCDD_basedir, 'LastExt')

    #folders in repository
    Gi_repository = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\LC-PrL-DREADDs_Self-Admin_Analysis\cue_analysis\Gi-DREADDs'%(user)
    Gi_results = os.path.join(Gi_repository, 'results')
    Gi_models = os.path.join(Gi_repository, 'population_data')

    #cluster list files
    Gi_cueRein_cluster_labels = np.load(os.path.join(Gi_cueRein_dir, 'cluster_list_per_session_CueTests Gi-DREADDs.npy'))
    Gi_cueReinCNO_labels = np.load(os.path.join(Gi_cueReinCNO_dir, 'cluster_list_per_session_CueTests Gi-DREADDs.npy'))
    Gi_cueReinPersist_labels = np.load(os.path.join(Gi_cueReinPersist_dir, 'cluster_list_per_session_CueTests Gi-DREADDs.npy'))

except:
    user = 'OtisLab'
    main_dir = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\LC-PrL-DREADDs_Self-Admin_Analysis\cue_analysis\LC-PrL-DREADDs'%(user)
    main_results = os.path.join(main_dir, 'results')

    #all CueRein Data
    ALL_cueRein_dir = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\PFC Self-Admin Analysis\PFC Self Admin Data\CueRein'%(user)

    #project datasets folder in DropBox
    LCDD_basedir = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\LC-PrL DREADDs Self Admin Analysis\Controls'%(user)
    LCDD_cueRein_dir = os.path.join(LCDD_basedir, 'CueRein')
    LCDD_cueReinCNO_dir = os.path.join(LCDD_basedir, 'CueReinCNO')
    LCDD_cueReinPersist_dir = os.path.join(LCDD_basedir, 'CueReinPersist')
    LCDD_lastEXT_dir = os.path.join(LCDD_basedir, 'LastExt')

    #folders in repository
    LCDD_repository = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\LC-PrL-DREADDs_Self-Admin_Analysis\cue_analysis\LCDD'%(user)
    LCDD_results = os.path.join(LCDD_repository, 'results')
    LCDD_models = os.path.join(LCDD_repository, 'population_data')

    #cluster list files
    LCDD_cueRein_cluster_labels = np.load(os.path.join(LCDD_cueRein_dir, 'cluster_list_per_session_CueTests Control.npy'))
    LCDD_cueReinCNO_labels = np.load(os.path.join(LCDD_cueReinCNO_dir, 'cluster_list_per_session_CueTests Control.npy'))
    LCDD_cueReinPersist_labels = np.load(os.path.join(LCDD_cueReinPersist_dir, 'cluster_list_per_session_CueTests Control.npy'))

    #project datasets folder in DropBox
    Gi_basedir = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Project Datasets\LC-PrL DREADDs Self Admin Analysis\Gi-DREADDs'%(user)
    Gi_cueRein_dir = os.path.join(Gi_basedir, 'CueRein')
    Gi_cueReinCNO_dir = os.path.join(Gi_basedir, 'CueReinCNO')
    Gi_cueReinPersist_dir = os.path.join(Gi_basedir, 'CueReinPersist')
    Gi_lastEXT_dir = os.path.join(Gi_basedir, 'LastExt')

    #folders in repository
    Gi_repository = r'C:\Users\%s\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\LC-PrL-DREADDs_Self-Admin_Analysis\cue_analysis\Gi-DREADDs'%(user)
    Gi_results = os.path.join(Gi_repository, 'results')
    Gi_models = os.path.join(Gi_repository, 'population_data')

    #cluster list files
    Gi_cueRein_cluster_labels = np.load(os.path.join(Gi_cueRein_dir, 'cluster_list_per_session_CueTests Gi-DREADDs.npy'))
    Gi_cueReinCNO_labels = np.load(os.path.join(Gi_cueReinCNO_dir, 'cluster_list_per_session_CueTests Gi-DREADDs.npy'))
    Gi_cueReinPersist_labels = np.load(os.path.join(Gi_cueReinPersist_dir, 'cluster_list_per_session_CueTests Gi-DREADDs.npy'))

print('User:', user)
print('Base directory:', main_dir)
print('Results directory:', main_results)

ALL_cueRein_animals = [
    'CTL1',
    'ER-L1',
    'ER-L2',
    'IG-19',

    'LCDD-PGa1',
    'LCDD-PGa3',
    'LCDD-PGa4',
    'LCDD-PGa5',
    'LCDD-PGa6', 

    'LCDD-PGa-T1',
    'LCDD-PGa-T2',
    'LCDD-PGa-T3',
    'LCDD-PGa-T4',
    'LCDD-PGa-T5',

    'PGa-T1',
    'PGa-T2',
    'PGa-T3'

]

#LC animals of interest
LCDD_cueRein_animals = [
    'LCDD-PGa4',
    'LCDD-PGa5',
    'LCDD-PGa6',

    'PGa-T1',
    'PGa-T2',
    'PGa-T3'
    ]  
LCDD_cueReinCNO_animals = [
    'LCDD-PGa4',
    'LCDD-PGa5',
    'LCDD-PGa6',

    'PGa-T1',
    'PGa-T2',
    ]  
LCDD_cueReinPersist_animals = [ 
    'LCDD-PGa4',
    'LCDD-PGa5',
    'LCDD-PGa6',

    'PGa-T1',
    'PGa-T2',
    'PGa-T3'
    ]  

#LCDD last Ext animals
LCDD_lastExt_animals = [
    'LCDD-PGa5',
    'LCDD-PGa6',

    'PGa-T1',
    'PGa-T2',
]

#Gi animals of interest
Gi_cueRein_animals = [
    'LCDD-PGa1',
    'LCDD-PGa3',

    'LCDD-PGa-T1',
    'LCDD-PGa-T2',
    'LCDD-PGa-T3',
    'LCDD-PGa-T4',
    'LCDD-PGa-T5'
    ]  
Gi_cueReinCNO_animals = [
    'LCDD-PGa1',
    'LCDD-PGa3',

    'LCDD-PGa-T1',
    'LCDD-PGa-T2',
    'LCDD-PGa-T3',
    'LCDD-PGa-T4',
    'LCDD-PGa-T5'
    ]  
Gi_cueReinPersist_animals = [ 
    'LCDD-PGa1',
    'LCDD-PGa3',

    'LCDD-PGa-T1',
    'LCDD-PGa-T2',
    'LCDD-PGa-T3',
    'LCDD-PGa-T4',
    'LCDD-PGa-T5'
    ]  

#Gi lastExt animals of interest
Gi_lastExt_animals = [
    'LCDD-PGa1',
    'LCDD-PGa3',

    'LCDD-PGa-T1',
    'LCDD-PGa-T2',
    'LCDD-PGa-T3',
    'LCDD-PGa-T4',
    'LCDD-PGa-T5'
]
# Out:
# User: jboqu
# Base directory: C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\LC-PrL-DREADDs_Self-Admin_Analysis\cue_analysis\LC-PrL-DREADDs
# Results directory: C:\Users\jboqu\Dropbox\2P Imaging Projects\Beth\Josh\Repositories\LC-PrL-DREADDs_Self-Admin_Analysis\cue_analysis\LC-PrL-DREADDs\results

# %%
#frame rate variables
frameaveraging = 4
timebetweenframes = 33.3333
framerate = 30
framerate = timebetweenframes/frameaveraging #raw frame rate
averagedframerate = timebetweenframes/frameaveraging #averaged frame rate
print('Frame rate:', framerate)
print('Averaged frame rate:', averagedframerate)

#window size variables
pre_window_size = int(10*framerate)
window_size =  int((pre_window_size*2)+(3*framerate))
post_window_size = window_size - pre_window_size
baselinefirstframe = 0
baselinelastframe = int(1*framerate)
infusionframe = int(pre_window_size+(3*framerate))
print('Prewindow size:', pre_window_size)
print('Window size:', window_size)
print('Postwindow size:', post_window_size)

#set cell tracking
tracking = 'No' ### 'Yes' or 'No'
sorting = 'Yes' ### 'Yes' or 'No'
sorttoearly = 'No' ###'Yes' or 'No'; This is for sorting, but align to early data. 'Sorting' must also be Yes
csv_id_for_tracking = 'CUE-DRUG-TMT'

#tracking
if tracking == 'Yes':
    population_active_tracked_early = np.nan*np.ones((1,window_size))
    population_active_tracked_middle = np.nan*np.ones((1,window_size))
    population_active_tracked_late = np.nan*np.ones((1,window_size))
    print ('Cell Tracking')
else:
    print ('No Cell Tracking')
# Out:
# Frame rate: 8.333325
# Averaged frame rate: 8.333325
# Prewindow size: 83
# Window size: 190
# Postwindow size: 107
# No Cell Tracking

# %% [markdown]
# ## Multivoxel Pattern Analysis *(decoding)*

# %% [markdown]
# ### Pilot

# %%
#import libraries
import numpy as np
from os import system
from IPython.display import clear_output
from numba import jit, cuda
from pandas import plotting
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay

#classifiers and models
from sklearn.svm import SVC, SVR
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.linear_model import LogisticRegression
from hyperopt import fmin, hp, tpe, Trials, space_eval, STATUS_OK
from sklearn.tree import DecisionTreeClassifier


#preproccesing
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score


import traceback
from statsmodels.distributions.empirical_distribution import ECDF

from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
import logging
from io import StringIO
import smtplib

# %%
#email alert exception handler

def send_email_crash_notification(crash_message):
    email = 'j.boquiren98@gmail.com'
    send_to_email = 'j.boquiren98@gmail.com'
    subject = 'Python application CRASHED!'
    msg = MIMEMultipart()
    msg['From'] = email
    msg['To'] = send_to_email
    msg['Subject'] = subject
    message = crash_message
    msg.attach(MIMEText(message, 'plain'))
    
    # Send the message via SMTP server.
    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.ehlo()
    server.starttls()
    server.login('j.boquiren98@gmail.com', 'eqepindlhavrnwvm')
    text = msg.as_string()
    server.sendmail(email, send_to_email, text)
    server.quit()
    print('Email sent to ' + str(send_to_email))
    return True

# %%
#model variables
# SPACE = {
#         'kernel': ['rbf'], 
#         'gamma': np.arange(.0001, 10, 10),
#         'C': np.arange(.1, 100, 10)
#         }
CLASSIFIER = SVC()
CROSS_VALIDATION = 5
NUM_ITERATIONS = 10
OBJECT = StandardScaler(with_mean=True)
DIMENSION_REDUCTION = PCA(n_components=10)
MODEL = RandomForestClassifier(n_estimators=5)

# %%
#decoding variables of interest
decoding = 'Neuron'
variable = 'Cue'
numclusters = 4

#initialize epochs
baseline_epoch = [0,8]
response_epoch = [pre_window_size, pre_window_size+12]

numshuffles = 1 
uniquelabels = np.arange(numclusters)
numneuronsincluster = np.nan*np.ones((numclusters,))

# %%
#date of iteration
date = '6-29-23'

#decoding results base directory
decoding_results_dir = os.path.join(main_results, 'decoding')

print('-----')
iteration_results = os.path.join(decoding_results_dir, date)
if os.path.exists(iteration_results):
    print('Iteration results folder exists for:', date)
else:
    os.mkdir(iteration_results)
    print('Made iteration results folder for:', date)
print('-----\n')

print('-----')
iteration_dictionaries = os.path.join(iteration_results, 'dictionaries')
if os.path.exists(iteration_dictionaries):
    print('Iteration dictionaries folder exists for:', date)
else:
    os.mkdir(iteration_dictionaries)
    print('Made iteration dictionaries folder for:', date)
#lines to be written in .txt file
lines = ['Decoding: ' + str(decoding),
        'Variable of interest: ' + str(variable),
        'Num-clusters: ' + str(numclusters),
        '\n',
        'MODEL INFO',
        'Model: ' + str(MODEL), 
        # 'Space: ' + str(SPACE), 
        'Classifier: ' + str(CLASSIFIER),
        'Dimension-reduction: ' + str(DIMENSION_REDUCTION),
        # 'Cross-validation: ' + str(CROSS_VALIDATION),
        'Standardization: ' + str(OBJECT),
        'Num-iterations: ' + str(NUM_ITERATIONS)]

print('-----\n')
#writing to file
file_name = '%s-model.txt'%(date)
try: 
    print('-----')
    model_file = open(os.path.join(iteration_results, file_name), 'r')
    print('Model file, %s, already exists!'%(file_name))
    override = input('Overwrite current file? [y/n]')
    if override == 'y':
        with open(os.path.join(iteration_results, file_name), 'w') as f:
            for line in lines:
                f.write(line)
                f.write('\n')
            print('Overwrote text file for date:', date)
        f.close()
    else:
        print('File not overwritten.')
except:
    with open(os.path.join(iteration_results, file_name), 'w') as f:
        for line in lines:
            f.write(line)
            f.write('\n')
        print('Made text file for date:', date)
    f.close()
print('-----')
# Out:
# -----
# Iteration results folder exists for: 6-29-23
# -----
#
# -----
# Iteration dictionaries folder exists for: 6-29-23
# -----
#
# -----
# Model file, 6-29-23-model.txt, already exists!
# Overwrote text file for date: 6-29-23
# -----

# %% [markdown]
# ### Algorithm

# %%
#TRAINING DATA

#initialize group(s)
groups = ['CueRein', 'CueRein']
indir_list = [LCDD_cueRein_dir, Gi_cueRein_dir]
animals_of_interest_list = [LCDD_cueRein_animals, Gi_cueRein_animals]

print('========== STARTING ==========')

"""
current set up averages across neurons, resulting in a dataframe with average neuronal activity for each trial across windowsize
with a target variable as the last index
"""
print('...gathering data...')
train_set = []
train_target = []
for index in range(len(groups)):
    animals_of_interest = animals_of_interest_list[index]
    indir = indir_list[index]
    for animal in animals_of_interest:
        fovs = next(os.walk(os.path.join(indir, animal)))[1]
        for fov in sorted(fovs):
            trials = np.load(os.path.join(indir, animal, fov, 'alignedActiveLeverCueData.npy'))
            flags = np.load(os.path.join(indir, animal, fov, 'classificationFlags.npy'))
            for neuron in range(trials.shape[2]):
                for trial in range(trials.shape[0]):
                    train_set.append(trials[trial,:,neuron])
                    train_target.append(flags[trial])
#X and y training data
X = np.array(train_set)
y = np.array(train_target)

print('...standardizing data...')
#standardize data
standardize = OBJECT
stand_X = standardize.fit_transform(X)

print('...reducing data...')
#reduce dimensions while maintaining variance
reduction = DIMENSION_REDUCTION
reduced_X = reduction.fit_transform(stand_X)

print('...training data...')
# #accuracy
MODEL.fit(reduced_X, y)

print('========== FINISHED ==========')
# Out:
# ========== STARTING ==========
# ...gathering data...
# ...standardizing data...
# ...reducing data...
# ...training data...
# ========== FINISHED ==========

# %%
#SHUFFLE

groups = ['CueReinPersist', 'CueReinPersist']
indir_list = [LCDD_cueReinPersist_dir, Gi_cueReinPersist_dir]
animals_of_interest_list = [LCDD_cueReinPersist_animals, Gi_cueReinPersist_animals]

print('========== STARTING ==========')

shuffle_arr = []
for index in range(len(groups)):
    animals_of_interest = animals_of_interest_list[index]
    indir = indir_list[index]
    for animal in animals_of_interest:
        fovs = next(os.walk(os.path.join(indir, animal)))[1]
        for fov in sorted(fovs):
            trials = np.load(os.path.join(indir, animal, fov, 'alignedActiveLeverCueData.npy'))
            flags = np.load(os.path.join(indir, animal, fov, 'classificationFlags.npy'))

            num_trials = trials.shape[0]
            numneuronsinfov = trials.shape[2]
            if num_trials >= 6:
                positives = len(flags[flags==1])
                negatives = len(flags[flags==0])
                if positives < 3 or negatives < 3:
                    activeflag = np.hstack((np.zeros((int(len(flags)/2))), np.ones((int(len(flags)/2)))))
                else:
                    activeflag = np.hstack((np.zeros((negatives)), 
                                            np.ones((positives))))
                for neuron in range(numneuronsinfov):
                    y = activeflag 
                    X = trials[:,:,neuron]
                    X[np.where(np.isnan(X))] = np.nanmean(X)
                    stand_X_test = standardize.fit_transform(X)
                    reduction = DIMENSION_REDUCTION
                    reduced_X_test = reduction.fit_transform(stand_X_test)
                    yhat = MODEL.predict(reduced_X_test)
                    accuracy = accuracy_score(y, yhat)
                    shuffle_arr.append(accuracy)

#shuffle results
shuffled_shuffle_arr = np.random.permutation(shuffle_arr)

print('========== FINISHED ==========')
# Out:
# ========== STARTING ==========
# ========== FINISHED ==========

# %%
#EXPERIMENTAL

groups = ['CueReinCNO']
indir_list = [Gi_cueReinCNO_dir]
animals_of_interest_list = [Gi_cueReinCNO_animals]

print('========== STARTING ==========')

xp_arr = []
for index in range(len(groups)):
    animals_of_interest = animals_of_interest_list[index]
    indir = indir_list[index]
    for animal in animals_of_interest:
        fovs = next(os.walk(os.path.join(indir, animal)))[1]
        for fov in sorted(fovs):
            trials = np.load(os.path.join(indir, animal, fov, 'alignedActiveLeverCueData.npy'))
            flags = np.load(os.path.join(indir, animal, fov, 'classificationFlags.npy'))

            num_trials = trials.shape[0]
            numneuronsinfov = trials.shape[2]
            if num_trials >= 6:
                positives = len(flags[flags==1])
                negatives = len(flags[flags==0])
                if positives < 3 or negatives < 3:
                    activeflag = np.hstack((np.zeros((int(len(flags)/2))), np.ones((int(len(flags)/2)))))
                else:
                    activeflag = np.hstack((np.zeros((negatives)), 
                                            np.ones((positives))))
                for neuron in range(numneuronsinfov):
                    y = activeflag 
                    X = trials[:,:,neuron]
                    X[np.where(np.isnan(X))] = np.nanmean(X)

                    stand_X_test = standardize.fit_transform(X)
                    reduction = DIMENSION_REDUCTION
                    reduced_X_test = reduction.fit_transform(stand_X_test)
                    yhat = MODEL.predict(reduced_X_test)
                    accuracy = accuracy_score(y, yhat)
                    xp_arr.append(accuracy)

print('========== FINISHED ==========')
# Out:
# ========== STARTING ==========
# ========== FINISHED ==========

# %%
#CONTROL

groups = ['CueReinCNO']
indir_list = [LCDD_cueReinCNO_dir]
animals_of_interest_list = [LCDD_cueReinCNO_animals]

print('========== STARTING ==========')

LCDD_acc_arr = []
for index in range(len(groups)):
    animals_of_interest = animals_of_interest_list[index]
    indir = indir_list[index]
    for animal in animals_of_interest:
        fovs = next(os.walk(os.path.join(indir, animal)))[1]
        for fov in sorted(fovs):
            trials = np.load(os.path.join(indir, animal, fov, 'alignedActiveLeverCueData.npy'))
            flags = np.load(os.path.join(indir, animal, fov, 'classificationFlags.npy'))

            num_trials = trials.shape[0]
            numneuronsinfov = trials.shape[2]
            if num_trials >= 6:
                positives = len(flags[flags==1])
                negatives = len(flags[flags==0])
                if positives < 3 or negatives < 3:
                    activeflag = np.hstack((np.zeros((int(len(flags)/2))), np.ones((int(len(flags)/2)))))
                else:
                    activeflag = np.hstack((np.zeros((negatives)), 
                                            np.ones((positives))))
                for neuron in range(numneuronsinfov):
                    y = activeflag 
                    X = trials[:,:,neuron]
                    X[np.where(np.isnan(X))] = np.nanmean(X)

                    stand_X_test = standardize.fit_transform(X)
                    reduction = DIMENSION_REDUCTION
                    reduced_X_test = reduction.fit_transform(stand_X_test)
                    yhat = MODEL.predict(reduced_X_test)
                    accuracy = accuracy_score(y, yhat)
                    LCDD_acc_arr.append(accuracy)

print('========== FINISHED ==========')
# Out:
# ========== STARTING ==========
# ========== FINISHED ==========

# %%
#stats
LC_t, LC_p = stats.ttest_ind(shuffle_arr, LCDD_acc_arr, equal_var=False)
Gi_t, Gi_p = stats.ttest_ind(shuffle_arr, xp_arr, equal_var=False)

control_mean = np.mean(shuffle_arr)
control_sem = stats.sem(shuffle_arr)

LC_mean = np.mean(LCDD_acc_arr)
LC_sem = stats.sem(LCDD_acc_arr)

xp_mean = np.mean(xp_arr)
xp_sem = stats.sem(xp_arr)

dict_arr = []

dict_arr.append({
    'Mean': '{0:.3g}'.format(control_mean),
    'SEM': '{0:.3g}'.format(control_sem),
    'T-val': '--',
    'P-val': '--',
})

dict_arr.append({
    'Mean': '{0:.3g}'.format(LC_mean),
    'SEM': '{0:.3g}'.format(LC_sem),
    'T-val': '{0:.3g}'.format(LC_t),
    'P-val': '{0:.3g}'.format(LC_p),
})
dict_arr.append({
    'Mean': '{0:.3g}'.format(xp_mean),
    'SEM': '{0:.3g}'.format(xp_sem),
    'T-val': '{0:.3g}'.format(Gi_t),
    'P-val': '{0:.3g}'.format(Gi_p),
})

stats_df = pd.DataFrame(dict_arr)
stats_df
# Out:
#     Mean      SEM  T-val     P-val
# 0  0.635  0.00272     --        --
# 1  0.642  0.00109  -2.46    0.0139
# 2  0.525  0.00494   19.5  6.38e-72

# %%
#plots
day = 'CueReinCNO'
sns.set_style('darkgrid')
fig, ax = plt.subplots(1, 1, figsize = (12,4))

ax.xaxis.tick_top()
ax.yaxis.tick_right()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

sns.kdeplot(shuffle_arr, cumulative=True, color='k', linestyle='--', label='Shuffle')
sns.ecdfplot(shuffle_arr, linewidth=.5, alpha =.7, color='k')

sns.kdeplot(LCDD_acc_arr, cumulative=True, color='blue', label='LCDD')
sns.ecdfplot(LCDD_acc_arr, linewidth=.5, alpha =.7, color='blue')


sns.kdeplot(xp_arr, cumulative=True, color='red', label='Gi-DREADDs')
sns.ecdfplot(xp_arr, linewidth=.5, alpha =.7, color='red')

plt.legend(loc=2, fontsize=12)
plt.title('%s Comparison'%(day), fontsize=18, fontweight='bold')
ax.annotate('***training set: LCDD and Gi-DREADDs CueRein', (.65,.05))

table = ax.table(cellText=stats_df.values, 
                 colLabels=stats_df.columns, 
                 rowLabels=['Shuffle', 'LCDD', 'Gi-DREADDs'], 
                 rowColours =["lightgrey"]*4, 
                 colColours =["lightgrey"] * 10,
                 cellLoc = 'center',
                 loc='bottom')
table.scale(1, 3)

confirm = input('Save figure? (y/n)')
if confirm == 'y':
    plt.savefig(os.path.join(iteration_results, 'LC-PrL-DREADDs_SA_%s.PDF'%(day)), format ='PDF')
    print('Figure saved.')
else:
    print('Figure not saved.')
# Out:
# Figure saved.

# %% [markdown]
# ### AUROC Analysis

# %%
#TRAINING DATA

#initialize group(s)
groups = ['CueRein', 'CueRein', 'CueRein']
indir_list = [ALL_cueRein_dir, LCDD_cueRein_dir, Gi_cueRein_dir]
animals_of_interest_list = [ALL_cueRein_animals, LCDD_cueRein_animals, Gi_cueRein_animals]

print('========== STARTING ==========')

print('...gathering data...')
train_set = []
train_target = []
for index in range(len(groups)):
    animals_of_interest = animals_of_interest_list[index]
    indir = indir_list[index]
    for animal in animals_of_interest:
        try:
            fovs = next(os.walk(os.path.join(indir, animal)))[1]
            for fov in sorted(fovs):
                trials = np.load(os.path.join(indir, animal, fov, 'alignedActiveLeverCueData.npy'))
                flags = np.load(os.path.join(indir, animal, fov, 'classificationFlags.npy'))
                for neuron in range(trials.shape[2]):
                    for trial in range(trials.shape[0]):
                        train_set.append(trials[trial,response_epoch[0]:response_epoch[1],neuron])
                        train_target.append(flags[trial])
        except:
            print('*** ERROR: %s has no file ***'%(animal))
#X and y training data
rand_index = np.random.randint(len(train_target), size=int(.5*len(train_target)))
X = np.array(train_set)
X_train_mean = np.mean(X, axis=0)
X_train = X[np.where(rand_index)]
y = np.array(train_target)
y_train = y[np.where(rand_index)]
X_test = X[np.where(~rand_index)]
y_test = y[np.where(~rand_index)]

X_pos = X_train[np.where(y_train==1)]
X_neg = X_train[np.where(y_train==0)]

print('...standardizing data...')
#standardize data
standardize = OBJECT
stand_X = standardize.fit_transform(X_train)
stand_X_test = standardize.fit_transform(X_test)

print('...reducing data...')
#reduce dimensions while maintaining variance
reduction = DIMENSION_REDUCTION
reduced_X = reduction.fit_transform(stand_X)
reduced_X_test = reduction.fit_transform(stand_X_test)

print('...training data...')
#fitting model
MODEL.fit(reduced_X, y_train)

print('...making probability predictions...')
#probability of accurate classifications
training_pred = MODEL.predict(reduced_X_test)
training_pred_proba = MODEL.predict_proba(reduced_X_test)[:,1]

print('...plotting...')
#data spread
fig, ax = plt.subplots(2, 2, figsize = (15,8))
sns.set_style('darkgrid')
ax[0,0].scatter(X_pos[:,0], X_pos[:,1], alpha=.2, color='red')
ax[0,0].legend(['Cue data'], loc=2)

ax[0,1].scatter(X_neg[:,0], X_neg[:,1], alpha=.2, color='grey')
ax[0,1].legend(['No-Cue data'], loc=2)

ax[1,0].scatter(X_train[:,0], X_train[:,1], alpha=.2)
ax[1,0].legend(['Original data'], loc=2)

ax[1,1].scatter(reduced_X[:,0], reduced_X[:,1], alpha=.4, color='red')
ax[1,1].legend(['Transformed Data'], loc=2)
plt.show()

#logistic regression plot
sns.regplot(x=training_pred_proba, y=y_test, logistic=True, ci=None)
plt.show()

#confusion matrix
cf_matrix = confusion_matrix(y_test, training_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in
                cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.savefig(os.path.join(iteration_results, 'CueRein-All_confusion-matrix_%s_%s.PDF'%(day, date)), format ='PDF')
plt.show()

#auROC curve
fpr, tpr, _ = roc_curve(y_test, training_pred)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot(color='blue')
roc_display.figure_.set_size_inches(5,5)
plt.plot([0, 1], [0, 1], color = 'k', linestyle='--')
plt.legend(['CueRein, AUC=%s'%('{0:.3g}'.format(roc_auc_score(y_test, training_pred_proba)))])
plt.title(day, fontsize=14, fontweight='bold')
plt.savefig(os.path.join(iteration_results, 'CueRein-All_auROC-curve_%s_%s.PDF'%(day, date)), format ='PDF')

plt.show()

print('========== FINISHED ==========')
# Out:
# ========== STARTING ==========
# ...gathering data...
# ...standardizing data...
# ...reducing data...
# ...training data...
# ...making probability predictions...
# ...plotting...
# ========== FINISHED ==========

# %%
#CONTROL DATA

day = 'CueRein'

#initialize group(s)
groups = [
    'CueRein',
    # 'CueReinCNO',
    # 'CueReinPersist'
    ]
indir_list = [
    LCDD_cueRein_dir,
    # LCDD_cueReinCNO_dir,
    # LCDD_cueReinPersist_dir
    ]
animals_of_interest_list = [
    LCDD_cueRein_animals,
    # LCDD_cueReinCNO_animals,
    # LCDD_cueReinPersist_animals
    ]

print('========== STARTING ==========')

"""
current set up averages across neurons, resulting in a dataframe with average neuronal activity for each trial across windowsize
with a target variable as the last index
"""
print('...gathering data...')
train_set = []
train_target = []
for index in range(len(groups)):
    animals_of_interest = animals_of_interest_list[index]
    indir = indir_list[index]
    for animal in animals_of_interest:
        fovs = next(os.walk(os.path.join(indir, animal)))[1]
        for fov in sorted(fovs):
            trials = np.load(os.path.join(indir, animal, fov, 'alignedActiveLeverCueData.npy'))
            flags = np.load(os.path.join(indir, animal, fov, 'classificationFlags.npy'))
            for neuron in range(trials.shape[2]):
                for trial in range(trials.shape[0]):
                    train_set.append(trials[trial,response_epoch[0]:response_epoch[1],neuron])
                    train_target.append(flags[trial])
#X and y training data
rand_index = np.random.randint(len(train_target), size=int(.5*len(train_target)))
X = np.array(train_set)
X_control_mean = np.mean(X, axis=0)
X_train = X[np.where(rand_index)]
y = np.array(train_target)
y_train = y[np.where(rand_index)]
X_test = X[np.where(~rand_index)]
y_test = y[np.where(~rand_index)]

print('...standardizing data...')
#standardize data
standardize = OBJECT
stand_X = standardize.fit_transform(X_train)
stand_X_test = standardize.fit_transform(X_test)

print('...reducing data...')
#reduce dimensions while maintaining variance
reduction = DIMENSION_REDUCTION
reduced_X = reduction.fit_transform(stand_X)
reduced_X_test = reduction.fit_transform(stand_X_test)

print('...training data...')
#fitting model
MODEL.fit(reduced_X, y_train)

print('...making probabily prediction...')
control_pred = MODEL.predict(reduced_X)
control_pred_proba = MODEL.predict_proba(reduced_X)[:,1]

print('...plotting...')
#original data
fig, ax = plt.subplots(1, 2, figsize = (10,4))
sns.set_style('darkgrid')
ax[0].scatter(X[:,0], X[:,1], alpha=.4)
ax[0].legend(['Original Data'], loc=2)
#transformed data
sns.set_style('darkgrid')
ax[1].scatter(reduced_X[:,0], reduced_X[:,1], alpha=.4, color='red')
ax[1].legend(['Transformed Data'], loc=2)
plt.show()

# #logistic regression curve
# sns.regplot(x=control_pred_proba, y=y_test, logistic=True, ci=None)
# plt.show()

#confusion matrix
cf_matrix = confusion_matrix(y_test, control_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in
                cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.savefig(os.path.join(iteration_results, 'LCDD_confusion-matrix_%s_%s.PDF'%(day, date)), format ='PDF')
plt.show()

#auROC curve
fpr, tpr, _ = roc_curve(y_test, control_pred_proba)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot(color='blue')
roc_display.figure_.set_size_inches(5,5)
plt.plot([0, 1], [0, 1], color = 'k', linestyle='--')
plt.legend(['LCDD, AUC=%s'%('{0:.3g}'.format(roc_auc_score(y_test, control_pred_proba)))], loc=4)
plt.title(day, fontsize=14, fontweight='bold')
plt.savefig(os.path.join(iteration_results, 'LCDD_auROC-curve_%s_%s.PDF'%(day, date)), format ='PDF')
plt.show()

print('========== FINISHED ==========')
# Out:
# ========== STARTING ==========
# ...gathering data...
# ...standardizing data...
# ...reducing data...
# ...training data...
# ...making probabily prediction...
# ...plotting...
# ========== FINISHED ==========

# %%
#EXPERIMENTAL DATA

day = 'CueRein'

#initialize group(s)
groups = [
    'CueRein',
    # 'CueReinCNO',
    # 'CueReinPersist'
    ]
indir_list = [
    Gi_cueRein_dir,
    # Gi_cueReinCNO_dir,
    # Gi_cueReinPersist_dir
    ]
animals_of_interest_list = [
    Gi_cueRein_animals,
    # Gi_cueReinCNO_animals,
    # Gi_cueReinPersist_animals
    ]

print('========== STARTING ==========')

"""
current set up averages across neurons, resulting in a dataframe with average neuronal activity for each trial across windowsize
with a target variable as the last index
"""
print('...gathering data...')
train_set = []
train_target = []
for index in range(len(groups)):
    animals_of_interest = animals_of_interest_list[index]
    indir = indir_list[index]
    for animal in animals_of_interest:
        fovs = next(os.walk(os.path.join(indir, animal)))[1]
        for fov in sorted(fovs):
            trials = np.load(os.path.join(indir, animal, fov, 'alignedActiveLeverCueData.npy'))
            # trials = np.mean(trials, axis=2) #average across neurons for each trial
            flags = np.load(os.path.join(indir, animal, fov, 'classificationFlags.npy'))
            for neuron in range(trials.shape[2]):
                for trial in range(trials.shape[0]):
                    train_set.append(trials[trial,response_epoch[0]:response_epoch[1],neuron])
                    train_target.append(flags[trial])
#X and y training data
rand_index = np.random.randint(len(train_target), size=int(.5*len(train_target)))
X = np.array(train_set)
X_xp_mean = np.mean(X, axis=0)
X_train = X[np.where(rand_index)]
y = np.array(train_target)
y_train = y[np.where(rand_index)]
X_test = X[np.where(~rand_index)]
y_test = y[np.where(~rand_index)]

print('...standardizing data...')
#standardize data
standardize = OBJECT
stand_X = standardize.fit_transform(X_train)
stand_X_test = standardize.fit_transform(X_test)

print('...reducing data...')
#reduce dimensions while maintaining variance
reduction = DIMENSION_REDUCTION
reduced_X = reduction.fit_transform(stand_X)
reduced_X_test = reduction.fit_transform(stand_X_test)

print('...training data...')
#fitting model
MODEL.fit(reduced_X, y_train)

print('...making probabily prediction...')
xp_pred = MODEL.predict(reduced_X)
xp_pred_proba = MODEL.predict_proba(reduced_X)[:,1]

print('...plotting...')
#original data
fig, ax = plt.subplots(1, 2, figsize = (10,4))
sns.set_style('darkgrid')
ax[0].scatter(X[:,0], X[:,1], alpha=.4)
ax[0].legend(['Original Data'], loc=2)
#transformed data
sns.set_style('darkgrid')
ax[1].scatter(reduced_X[:,0], reduced_X[:,1], alpha=.4, color='red')
ax[1].legend(['Transformed Data'], loc=2)
plt.show()

# #logistic regression curve
# sns.regplot(x=xp_pred_proba, y=y_test, logistic=True, ci=None)
# plt.show()

#confusion matrix
cf_matrix = confusion_matrix(y_test, xp_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in
                cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Reds')
plt.savefig(os.path.join(iteration_results, 'Gi-DREADDs_confusion-matrix_%s_%s.PDF'%(day, date)), format ='PDF')
plt.show()

#auROC curve
fpr, tpr, _ = roc_curve(y_test, xp_pred_proba)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot(color='red')
roc_display.figure_.set_size_inches(5,5)
plt.plot([0, 1], [0, 1], color = 'k', linestyle='--')
plt.legend(['Gi-DREADDs, AUC=%s'%('{0:.3g}'.format(roc_auc_score(y_test, xp_pred_proba)))], loc=4)
plt.title(day, fontsize=14, fontweight='bold')
plt.savefig(os.path.join(iteration_results, 'Gi-DREADDs_auROC-curve_%s_%s.PDF'%(day, date)), format ='PDF')
plt.show()

print('========== FINISHED ==========')
# Out:
# ========== STARTING ==========
# ...gathering data...
# ...standardizing data...
# ...reducing data...
# ...training data...
# ...making probabily prediction...
# ...plotting...
# ========== FINISHED ==========

# %%
mean_arr = np.mean((np.vstack((X_train_mean, X_control_mean, X_xp_mean))), axis=0)

plt.plot(X_train_mean, color='k', linestyle='--', label='Training data: All CueRein')
plt.plot(X_control_mean, color='blue', label='LCDD: CueRein')
plt.plot(X_xp_mean, color='red', label='Gi-DREADDs:CueRein')
plt.plot(mean_arr, color='grey', linestyle='dotted', label='Mean')
plt.legend(loc=3)
plt.title('Average Values Across Neurons in Response Interval', fontsize=12, fontweight='bold')
plt.savefig(os.path.join(iteration_results, 'response_averages_%s_%s.PDF'%(day, date)), format ='PDF')
plt.show()
